# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) 
import plotly.express as px

# %%
df = pd.read_excel("financial_loan.xlsx")

# %%
df.head()
# Out:
#         id address_state application_type emp_length              emp_title  \
# 0  1077430            GA       INDIVIDUAL   < 1 year                  Ryder
# 1  1072053            CA       INDIVIDUAL    9 years         MKC Accounting
# 2  1069243            CA       INDIVIDUAL    4 years  Chemat Technology Inc
# 3  1041756            TX       INDIVIDUAL   < 1 year    barnes distribution
# 4  1068350            IL       INDIVIDUAL  10+ years          J&J Steel Inc
#
#   grade home_ownership issue_date last_credit_pull_date last_payment_date  \
# 0     C           RENT 2021-02-11            2021-09-13        2021-04-13
# 1     E           RENT 2021-01-01            2021-12-14        2021-01-15
# 2     C           RENT 2021-01-05            2021-12-12        2021-01-09
# 3     B       MORTGAGE 2021-02-25            2021-12-12        2021-03-12
# 4     A       MORTGAGE 2021-01-01            2021-12-14        2021-01-15
#
# ...

# %%
df.tail()
# Out:
#            id address_state application_type emp_length  \
# 38571  803452            NJ       INDIVIDUAL   < 1 year
# 38572  970377            NY       INDIVIDUAL    8 years
# 38573  875376            CA       INDIVIDUAL    5 years
# 38574  972997            NY       INDIVIDUAL    5 years
# 38575  682952            NY       INDIVIDUAL    4 years
#
#                              emp_title grade home_ownership issue_date  \
# 38571         Joseph M Sanzari Company     C       MORTGAGE 2021-07-11
# 38572                        Swat Fame     C           RENT 2021-10-11
# 38573  Anaheim Regional Medical Center     D           RENT 2021-09-11
# 38574               Brooklyn Radiology     D           RENT 2021-10-11
# 38575                    Allen Edmonds     F           RENT 2021-07-11
#
#       last_credit_pull_date last_payment_date  ... sub_grade        term  \
# 38571            2021-05-16        2021-05-16  ...        C1   60 months
# ...

# %% [markdown]
# ### Metadata of Data

# %%
print("No of Rows:", df.shape[0])
# Out:
# No of Rows: 38576

# %%
print("No of Columns:", df.shape[1])
# Out:
# No of Columns: 24

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38576 entries, 0 to 38575
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     38576 non-null  int64
#  1   address_state          38576 non-null  object
#  2   application_type       38576 non-null  object
#  3   emp_length             38576 non-null  object
#  4   emp_title              37138 non-null  object
#  5   grade                  38576 non-null  object
#  6   home_ownership         38576 non-null  object
#  7   issue_date             38576 non-null  datetime64[ns]
#  8   last_credit_pull_date  38576 non-null  datetime64[ns]
#  9   last_payment_date      38576 non-null  datetime64[ns]
#  10  loan_status            38576 non-null  object
#  11  next_payment_date      38576 non-null  datetime64[ns]
#  12  member_id              38576 non-null  int64
#  13  purpose                38576 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# id                          0
# address_state               0
# application_type            0
# emp_length                  0
# emp_title                1438
# grade                       0
# home_ownership              0
# issue_date                  0
# last_credit_pull_date       0
# last_payment_date           0
# loan_status                 0
# next_payment_date           0
# member_id                   0
# purpose                     0
# sub_grade                   0
# term                        0
# verification_status         0
# annual_income               0
# dti                         0
# installment                 0
# int_rate                    0
# loan_amount                 0
# total_acc                   0
# total_payment               0
# dtype: int64

# %% [markdown]
# ### Data types

# %%
df.dtypes
# Out:
# id                                int64
# address_state                    object
# application_type                 object
# emp_length                       object
# emp_title                        object
# grade                            object
# home_ownership                   object
# issue_date               datetime64[ns]
# last_credit_pull_date    datetime64[ns]
# last_payment_date        datetime64[ns]
# loan_status                      object
# next_payment_date        datetime64[ns]
# member_id                         int64
# purpose                          object
# sub_grade                        object
# term                             object
# verification_status              object
# annual_income                   float64
# dti                             float64
# installment                     float64
# int_rate                        float64
# loan_amount                       int64
# total_acc                         int64
# ...

# %%
df.describe()
# Out:
#                  id                     issue_date  \
# count  3.857600e+04                          38576
# mean   6.810371e+05  2021-07-16 02:31:35.562007040
# min    5.473400e+04            2021-01-01 00:00:00
# 25%    5.135170e+05            2021-04-11 00:00:00
# 50%    6.627280e+05            2021-07-11 00:00:00
# 75%    8.365060e+05            2021-10-11 00:00:00
# max    1.077501e+06            2021-12-12 00:00:00
# std    2.113246e+05                            NaN
#
#                last_credit_pull_date              last_payment_date  \
# count                          38576                          38576
# mean   2021-06-08 13:36:34.193280512  2021-06-26 09:52:08.909166080
# min              2021-01-08 00:00:00            2021-01-08 00:00:00
# 25%              2021-04-15 00:00:00            2021-03-16 00:00:00
# 50%              2021-05-16 00:00:00            2021-06-14 00:00:00
# 75%              2021-08-13 00:00:00            2021-09-15 00:00:00
# ...

# %% [markdown]
# ### Total Loan Applications

# %%
total_loan_application = df['id'].count()
print("Total Loan Applications:", total_loan_application)
# Out:
# Total Loan Applications: 38576

# %% [markdown]
# ### MTD Total Loan Applications

# %%
latest_issue_date = df['issue_date'].max()
latest_year = latest_issue_date.year
latest_month = latest_issue_date.month

mtd_data = df[(df['issue_date'].dt.year == latest_year) & (df['issue_date'].dt.month == latest_month)]

mtd_loan_applications = mtd_data['id'].count()

print(f"MTD Loan Applications (for {latest_issue_date.strftime('%B %Y')}) : {mtd_loan_applications}")
# Out:
# MTD Loan Applications (for December 2021) : 4314

# %% [markdown]
# ### Total Funded Amount

# %%
total_funded_amount = df['loan_amount'].sum()
total_funded_amount_millions = total_funded_amount/1000000
print("Total Funded Amount: ${:.2f}M". format( total_funded_amount_millions))
# Out:
# Total Funded Amount: $435.76M

# %% [markdown]
# ### MTD - Total Funded Amount

# %%
latest_issue_date = df["issue_date"].max()
latest_issue_year = latest_issue_date.year
latest_issue_month = latest_issue_date.month

mtd_data  = df[(df["issue_date"].dt.year == latest_year) & (df["issue_date"].dt.month == latest_month)]

mtd_total_funded_amount = mtd_data["loan_amount"].sum()
mtd_total_funded_amount_millions = mtd_total_funded_amount / 1000000

print("MTD Total Funded Amount: ${:.2f}M". format (mtd_total_funded_amount_millions))
# Out:
# MTD Total Funded Amount: $53.98M

# %% [markdown]
# ### Total Amount Received

# %%
total_amount_received  = df["total_payment"].sum()
total_amount_received_millions = total_amount_received / 1000000
print("Total Amount Received: ${:.2f}M". format(total_amount_received_millions))
# Out:
# Total Amount Received: $473.07M

# %% [markdown]
# ### MTD Total Amount Received

# %%
latest_issue_date = df["issue_date"].max()
latest_issue_date_year = latest_issue_date.year
latest_issue_date_month = latest_issue_date.month

mtd_data = df[(df["issue_date"].dt.year == latest_year) & (df["issue_date"].dt.month == latest_month)]

mtd_total_amount_received = mtd_data["total_payment"].sum()
mtd_total_amount_received_millions  = mtd_total_amount_received / 1000000

print("MTD Total Amount Received: ${:.2f}M". format(mtd_total_amount_received_millions))
# Out:
# MTD Total Amount Received: $58.07M

# %% [markdown]
# ### Average Interest Rate

# %%
average_interest_rate = df["int_rate"].mean()
average_interest_rate_percentage = average_interest_rate * 100

print("Average Interest Rate: {:.2f}%". format( average_interest_rate_percentage))
# Out:
# Average Interest Rate: 12.05%

# %% [markdown]
# ### Average Debt-to-income Ratio

# %%
average_dti = df["dti"].mean()
average_dti_percentage = average_dti*100

print("Average Debt-to-income : {:.2f}%".format(average_dti_percentage))
# Out:
# Average Debt-to-income : 13.33%

# %% [markdown]
# ### Good Loan Metrics

# %%
good_loans = df[df["loan_status"].isin(["Fully Paid", "Current"])]

total_loan_applications = df["id"].count()

good_loan_applications = good_loans["id"].count()
good_loans_funded_amount = good_loans["loan_amount"].sum()
good_loans_received = good_loans["total_payment"].sum()

good_loan_funded_amount_millions = good_loans_funded_amount/1000000
good_loan_received_millions = good_loans_received/1000000

good_loan_percentage = (good_loan_applications / total_loan_applications) * 100

print("Good loan applications:", good_loan_applications)

print("Good loan funded amount (in millions): ${:.2f}M".format(good_loan_funded_amount_millions))

print("Good loan amount received (in millions): ${:.2f}M".format(good_loan_received_millions))

print("Percentage of Good loan Applications: {:.2f}%".format(good_loan_percentage))
# Out:
# Good loan applications: 33243
# Good loan funded amount (in millions): $370.22M
# Good loan amount received (in millions): $435.79M
# Percentage of Good loan Applications: 86.18%

# %% [markdown]
# ### Bad Loans Metrics

# %%
bad_loans = df[df["loan_status"].isin(["Charged Off"])]

total_loan_application = df["id"].count()

total_bad_loan_applications = bad_loans["id"].count()
total_bad_loans_funded_amount = bad_loans["loan_amount"].sum()
total_bad_loans_amount_received = bad_loans["total_payment"].sum()

total_bad_loans_funded_amount_millions = total_bad_loans_funded_amount / 1000000
total_bad_loans_amount_received_millions = total_bad_loans_amount_received / 1000000

percentage_of_bad_loan_applications = (total_bad_loan_applications/ total_loan_applications)*100

print("Total bad loan applications:", total_bad_loan_applications)
print("Bad Loans funded amount (in millions): ${:.2f}".format(total_bad_loans_funded_amount_millions))
print("Bad Loans Amount Received (in millions): ${:.2f}".format(total_bad_loans_amount_received_millions))

print("Percentage of bad loans: {:.2f}% ". format(percentage_of_bad_loan_applications))
# Out:
# Total bad loan applications: 5333
# Bad Loans funded amount (in millions): $65.53
# Bad Loans Amount Received (in millions): $37.28
# Percentage of bad loans: 13.82%

# %% [markdown]
# ### Monthly Trend by Issue Date for Total Funded Amount

# %%
monthly_funded = (
    df.sort_values("issue_date")
    .assign(month_name = lambda x : x["issue_date"].dt.strftime("%b %y"))
    .groupby("month_name", sort = False) ["loan_amount"]
    .sum()
    .div(100000)
    .reset_index(name = "loan_amount_millions")
)

plt.figure(figsize = (10, 5))
plt.fill_between(monthly_funded["month_name"], monthly_funded ["loan_amount_millions"], color = 'skyblue', alpha = 0.5)
plt.plot(monthly_funded["month_name"], monthly_funded["loan_amount_millions"], color = "blue", linewidth = 2)

for i, row in monthly_funded.iterrows():
    plt.text(i, row["loan_amount_millions"] + 0.1, f"{row["loan_amount_millions"]:.2f}",
             ha = "center", va = "bottom", fontsize = 9, rotation = 0, color = "black")

plt.title("Total Funded Amount by Month", fontsize = 14)
plt.xlabel("Month")
plt.ylabel("Funded Amount ( Millions)")
plt.xticks(ticks = range(len(monthly_funded)), label = monthly_funded["month_name"], rotation = 45)
plt.grid(True, linestyle = "--", alpha = 0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly Trends by Issue Date for Total Amount Received

# %%
monthly_received = (
    df.sort_values("issue_date")
    .assign(month_name = lambda x : x["issue_date"].dt.strftime("%b %y"))
    .groupby("month_name", sort = False) ["total_payment"]
    .sum()
    .div(100000)
    .reset_index(name = "received_amount_millions")
)

plt.figure(figsize = (10, 5))
plt.fill_between(monthly_funded["month_name"], monthly_received ["received_amount_millions"], color = 'lightgreen', alpha = 0.5)
plt.plot(monthly_received["month_name"], monthly_received["received_amount_millions"], color = "green", linewidth = 2)

for i, row in monthly_received.iterrows():
    plt.text(i, row["received_amount_millions"] + 0.1, f"{row["received_amount_millions"]:.2f}",
             ha = "center", va = "bottom", fontsize = 9, rotation = 0, color = "black")

plt.title("Total Received Amount by Month", fontsize = 14)
plt.xlabel("Month")
plt.ylabel("Received Amount ( Millions)")
plt.xticks(ticks = range(len(monthly_funded)), label = monthly_funded["month_name"], rotation = 45)
plt.grid(True, linestyle = "--", alpha = 0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Monthly Trends by Issue Date for Total Loan Applications

# %%
monthly_applications = (
    df.sort_values("issue_date")
    .assign(month_name = lambda x : x["issue_date"].dt.strftime("%b %y"))
    .groupby("month_name", sort = False) ["id"]
    .count()
    .reset_index(name = "loan_application_count")
)

plt.figure(figsize = (10, 5))
plt.fill_between(monthly_funded["month_name"], monthly_applications ["loan_application_count"], color = 'orange', alpha = 0.5)
plt.plot(monthly_applications["month_name"], monthly_applications["loan_application_count"], color = "darkorange", linewidth = 2)

for i, row in monthly_applications.iterrows():
    plt.text(i, row["loan_application_count"] + 0.1, f"{row["loan_application_count"]:.2f}",
             ha = "center", va = "bottom", fontsize = 9, rotation = 0, color = "black")

plt.title("Total Loan Applications by Month", fontsize = 14)
plt.xlabel("Month")
plt.ylabel("Number of Application")
plt.xticks(ticks = range(len(monthly_funded)), label = monthly_funded["month_name"], rotation = 45)
plt.grid(True, linestyle = "--", alpha = 0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State for Total Funded Amount

# %%
state_funding = df.groupby("address_state")["loan_amount"].sum().sort_values(ascending = True)
state_funding_thousands = state_funding / 1000

plt.figure(figsize=(12,10))
bars = plt.barh(state_funding_thousands.index, state_funding_thousands.values, color = "lightcoral")

for bar in bars:
    width = bar.get_width()
    plt.text(width + 10, bar.get_y() + bar.get_height() / 2,
        f'{width:,.0f}k', va = "center", fontsize = 9)


plt.title("Total Funded Amount by State (in thousands)")
plt.xlabel("Funded Amount ( ₹'000)")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State for Total Amount Received

# %%
state_received_amount = df.groupby("address_state")["total_payment"].sum().sort_values(ascending = True)
state_received_amount_millions = state_received_amount / 1000000

plt.figure(figsize=(12,10))
bars = plt.barh(state_received_amount_millions.index, state_received_amount_millions.values, color = "lightcoral")

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2,
        f'{width:,.2f}M', va = "center", fontsize = 9)


plt.title("Total Amount Received by State (in Millions)")
plt.xlabel("Received Amount ( ₹ Millions)")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Regional Analysis by State for Total Loan Applications

# %%
state_loan_applications = df.groupby("address_state")["id"].count().sort_values(ascending = True)
state_loan_applications_thousands = state_loan_applications / 1000

plt.figure(figsize=(12,10))
bars = plt.barh(state_loan_applications_thousands.index, state_loan_applications_thousands.values, color = "lightcoral")

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2,
        f'{width:,.3f}K', va = "center", fontsize = 9)


plt.title("Total Loan Applications Received by State (in thousands)")
plt.xlabel("Received Applications ( Thousands)")
plt.ylabel("State")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Term Analysis by Total Funded Amount

# %%
term_funding = df.groupby('term')['loan_amount'].sum()

term_funding_millions = term_funding / 1000000

plt.figure(figsize = (5, 5))
plt.pie(
    term_funding_millions,
    labels = term_funding_millions.index,
    autopct = lambda p: f"{p:.1f}%\n${p*sum(term_funding_millions)/100:.1f}M",
    startangle = 90,
    wedgeprops = {'width': 0.4}
)
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color = 'white'))
plt.title("Total Funded Amount by Term (in $ Millions)")
plt.show()

# %% [markdown]
# ### Loan Term Analysis by Total Amount Received

# %%
term_receiving = df.groupby('term')['total_payment'].sum()

term_receiving_millions = term_receiving / 1000000

plt.figure(figsize = (5, 5))
colors = ['#66c2a5', '#fc8d62']
plt.pie(
    term_receiving_millions,
    labels = term_receiving_millions.index,
    autopct = lambda p: f"{p:.2f}%\n${p*sum(term_receiving_millions) / 100:.2f}M",
    startangle = 90,
    colors=colors,
    wedgeprops = {'width': 0.4}
)
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color = 'white'))
plt.title("Total Amount Received by Term (in $ Millions)")
plt.show()

# %% [markdown]
# ### Loan Term Analysis by Total Loan Applications

# %%
term_loan_applications = df.groupby('term')['id'].count()

term_loan_applications_thousands = term_loan_applications / 1000

plt.figure(figsize = (5, 5))
colors = ['#66c2a5', '#fc8d62']
plt.pie(
    term_loan_applications_thousands,
    labels = term_loan_applications_thousands.index,
    autopct = lambda p: f"{p:.2f}%\n{p*sum(term_loan_applications_thousands) / 100:.2f}K",
    startangle = 90,
    colors=colors,
    wedgeprops = {'width': 0.4}
)
plt.gca().add_artist(plt.Circle((0, 0), 0.70, color = 'white'))
plt.title("Total Loan Applications by Term (in Thousands)")
plt.show()

# %% [markdown]
# ### Employee Length by Total Funded Amount

# %%
emp_funding = df.groupby("emp_length")["loan_amount"].sum().sort_values()
emp_funding_millions = emp_funding / 10000000

plt.figure(figsize = (12,6))

bars = plt.barh(emp_funding_millions.index, emp_funding_millions, color = 'purple')

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2,
        f"₹{width:,.2f}M", va = "center", fontsize = 9)


plt.xlabel("Funded Amount (₹ in Millions)")
plt.title("Total Funded Amount by Employment Length (in Millions)")
plt.grid(axis = 'x', linestyle = '--', alpha = 0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Employee Length by Total Amount Received

# %%
emp_amount_received = df.groupby("emp_length")["total_payment"].sum().sort_values()
emp_amount_received_millions = emp_amount_received / 10000000

plt.figure(figsize = (12,6))

bars = plt.barh(emp_amount_received_millions.index, emp_amount_received_millions, color = 'purple')

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2,
        f"₹{width:,.2f}M", va = "center", fontsize = 9)


plt.xlabel("Amount Received (₹in Millions)")
plt.title("Total Amount Received by Employment Length (in Millions)")
plt.grid(axis = 'x', linestyle = '--', alpha = 0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Employee Length by Total Loan Applications

# %%
emp_loan_applications = df.groupby("emp_length")["id"].count().sort_values()
emp_loan_applications_thousands = emp_loan_applications / 1000

plt.figure(figsize = (12,6))

bars = plt.barh(emp_loan_applications_thousands.index, emp_loan_applications_thousands, color = 'purple')

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2,
        f"{width:,.2f}K", va = "center", fontsize = 9)


plt.xlabel("Loan Applications ( in Thousands)")
plt.title("Total Loan Applications by Employment Length (in thousands)")
plt.grid(axis = 'x', linestyle = '--', alpha = 0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose by Total Funded Amount

# %%
purpose_funding = df.groupby("purpose")["loan_amount"].sum().sort_values()

purpose_funding_millions = purpose_funding/1000000

plt.figure(figsize = (14, 6))
bars = plt.barh(purpose_funding_millions.index, purpose_funding_millions.values, color = "skyblue")

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height()/2,
            f"{width:.2f}M", va = "center", fontsize = 9)

plt.title("Total Funded Amount by Loan Purpose (₹ in Millions)", fontsize = 14)
plt.xlabel("Funded Amount (₹ in Millions)")
plt.ylabel("Loan Purpose")
plt.grid(axis = "x", linestyle = "--", alpha = 0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose by Total Amount Received

# %%
purpose_amount_received = df.groupby("purpose")["total_payment"].sum().sort_values(ascending = True)

purpose_amount_received_millions = purpose_amount_received/1000000

plt.figure(figsize = (10, 6))
bars = plt.barh(purpose_amount_received_millions.index, purpose_amount_received_millions.values, color = "skyblue")

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height()/2,
            f"{width:.2f}M", va = "center", fontsize = 9)

plt.title("Total Amount Received by Loan Purpose (₹ in Millions)", fontsize = 14)
plt.xlabel("Amount Received (₹ in Millions)")
plt.ylabel("Loan Purpose")
plt.grid(axis = "x", linestyle = "--", alpha = 0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Loan Purpose by Total Loan Applications

# %%
purpose_loan_applications = df.groupby("purpose")["id"].count().sort_values(ascending = True)

purpose_loan_applications_thousands = purpose_loan_applications/1000

plt.figure(figsize = (10, 6))
bars = plt.barh(purpose_loan_applications_thousands.index, purpose_loan_applications_thousands.values, color = "skyblue")

for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height()/2,
            f"{width:.2f}K", va = "center", fontsize = 9)

plt.title("Total Loan Applications Received by Loan Purpose (in Thousands)", fontsize = 14)
plt.xlabel("Loan Applications (Thousands)")
plt.ylabel("Loan Purpose")
plt.grid(axis = "x", linestyle = "--", alpha = 0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Home Ownership by Total Funded Amount

# %%
home_funding = df.groupby("home_ownership")["loan_amount"].sum().reset_index()
home_funding["loan_amount_millions"] = home_funding["loan_amount"] / 1000000

fig = px.treemap(
    home_funding,
    path= ["home_ownership"],
    values = 'loan_amount_millions',
    color = 'loan_amount_millions',
    color_continuous_scale = 'blues',
    title = 'Total Funded Amount by Home Ownership (₹ MIllions)'
    
)

fig.show()

# %% [markdown]
# ### Home Ownership by Total Amount Received

# %%
home_receiving = df.groupby("home_ownership")["total_payment"].sum().reset_index()
home_receiving["loan_amount_millions"] = home_funding["total_payment"] / 1000000

fig = px.treemap(
    home_funding,
    path= ["home_ownership"],
    values = 'loan_amount_millions',
    color = 'loan_amount_millions',
    color_continuous_scale = 'blues',
    title = 'Total Received Amount by Home Ownership (₹ Millions)'
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_payment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[518], line 2
# ...

# %% [markdown]
# ### Home Ownership by Total Loan Application

# %%
home_receiving = df.groupby("home_ownership")["id"].count().reset_index()
home_receiving["applications_thousands"] = home_receiving["id"] / 1000

fig = px.treemap(
    home_receiving,
    path= ["home_ownership"],
    values = 'applications_thousands',
    color = 'applications_thousands',
    color_continuous_scale = 'blues',
    title = 'Total Loan Applications by Home Ownership (in Thousands)'
)

fig.show()
